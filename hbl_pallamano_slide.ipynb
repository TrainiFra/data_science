# %% [markdown]
# Librerie e collegamenti CSS

# %% [markdown]
# from IPython.core.display import HTML
#
# def css_styling():
#     styles = open("custom.css", "r").read()
#     return HTML(styles)
#
# css_styling()

# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="custom.css">
# Out:
# <link rel="stylesheet" type="text/css" href="custom.css">

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# impostazione stile grafici
# palette di colori, divisione della palette "Paired"
colori_soft=['#cab2d6', '#fdbf6f', '#b2df8a', '#a6cee3', '#ffff99', '#fb9a99']
colori_strong=['#6a3d9a', '#ff7f00', '#33a02c', '#1f78b4', '#b15928', '#e31a1c']
colori = colori_strong + colori_soft
## stile, scala delle griglia, dimensioni, palette default
sns.set(style="whitegrid",font_scale=1.3, rc={'figure.figsize':(8,6)}, palette=colori)

display(sns.color_palette(colori_soft))
sns.color_palette(colori_strong)
# Out:
# [(0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (1.0, 1.0, 0.6),
#  (0.984313725490196, 0.6039215686274509, 0.6)]
# [(0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745)]

# %%
hbl = pd.read_csv("csv/men_hbl_7_seasons_stats_modificato.csv", index_col=False);

# %% [markdown]
# <h1 style="font-family:'Impact'; font-size:120px; color:#FFDE00;">PALLAMANO</h1>

# %% [markdown]
# ## INTRODUZIONE

# %% [markdown]
# #### ***NAZIONALE MASCHILE***
#
# <img src="images/nazionale-maschile.png" width="700" height="650" alt='maschile'></img>

# %% [markdown]
# #### ***NAZIONALE FEMMINILE***
#
# <img src="images/nazionale-femminile.jpg" width="700" height="650" alt='femminile'></img>

# %% [markdown]
# ### Domande

# %% [markdown]
# 1. In quale zona del campo di tira più spesso? In quale si sbaglia meno?

# %% [markdown]
# 2. Quale giocatore è più preciso al tiro?

# %% [markdown]
# 3. Il portiere serve solo a difendere la porta?

# %% [markdown]
# 4.	Quale posizione ha la difesa più “pulita” e quale più “aggressiva”?

# %% [markdown]
# ## INFO DATASET

# %% [markdown]
# ***IL DATASET***
#
# Popolato utilizzando i referti del campionato tedesco (HBL) dal 2017 alla metà del 2024.
#
# <img src='images/hbl-logo.png' alt='Logo HBL 2026'></img>

# %% [markdown]
# | Dati | Descrizione |
# | :- | :- |
# | Cognome | Cognome del giocatore |
# | Nome | Nome del giocatore |
# | Squadra | Nome della squadra con cui gioca per la stagione corrente |
# | Posizione | Ruolo del giocatore in campo { GK (Portiere), LB (Terzino Sinistro), CB (Centrale), RB (Terzino Destro), P (Pivot), LW (Ala Sinistra), RW (Ala Destra) } |
# | Partite Giocate | Numero delle partite giocate durante la stagione |
# | Gol Totali | Numero totale di reti effettuate in tutta la stagione |
# | Tiri Sbagliati | Numero di tiri sbagliati effettuati in tutta la stagione |
# | Gol Azione | Numero di reti effettuate con un'azione di gioco |
# | Gol Rigore | Numero di reti effettuate con un tiro di rigore |
# | Percentuale Realizzazione | Percentuale di realizzazione di gol per la stagione in corso, calcolata come [ Gol Totali / (Gol Totali + Tiri Sbagliati) ] |
# | Assist | Numero di assist terminati con un gol per la stagione corrente |
# | Falli Tecnici | Numero di falli tecnici recevuti |
# | Intercetti | Numero di palloni intercettati durante la stagione |
# | Blocchi | Numero di blocchi effettuati |
# | Cartellino Giallo | Numero di cartellini gialli ricevuti durante la stagione |
# | 2 Minuti | Numero di esclusioni da 2 minuti ricevute durante la stagione |
# | Cartellino Rosso | Numero di cartellini rossi ricevuti durante la stagione |
# | Cartellino Blu | Numero di cartellini blu ricevuti durante la stagione |
# | Stagione | Nome della stagione corrente |
# | Categoria | Categoria di cui fa parte il giocatore {A, B} |

# %% [markdown]
# Dati mancati:
# - Numero di parate dei portieri
# - Contropiedi falliti
# - Minutaggio di ogni giocatore

# %% [markdown]
# ## DESCRIZIONE ANALISI

# %% [markdown]
# ### Risposta 1

# %% [markdown]
# <p class='domanda'> 1 - Quale posizione tira più spesso? Quale sbaglia meno?</p>
#
# <img src='campo.png' width="600" height="550" alt='campo'></img>

# %% [markdown]
# <img src='images/risposta1-a.jpg' alt='risposta1-a'></img>

# %% [markdown]
# <img src='images/risposta1-b.jpg' alt='risposta1-b'></img>

# %% [markdown]
# ### Risposta 2

# %% [markdown]
# <p class='domanda'>2 - Quale giocatore è più preciso al tiro? Vince chi ha più minutaggio, chi tira di più o l'esperienza?</p>

# %% [markdown]
# <img src='images/risposta2-a.jpg' alt='risposta2-a'></img>

# %% [markdown]
# <img src='images/risposta2-top.jpg' alt='risposta2-top'></img>

# %% [markdown]
# ### Risposta 3

# %% [markdown]
# <p class='domanda'>3 - Il portiere serve solo a difendere la porta?</p>

# %% [markdown]
# <img src='images/risposta3-c.jpg' alt='risposta3-c'></img>

# %% [markdown]
# <img src='images/risposta3-d.jpg' alt='risposta3-d' width=700, height=500></img>

# %% [markdown]
# ### Risposta 4

# %% [markdown]
# <p class='domanda'>4 - Quale posizione ha la difesa più “pulita” e quale più “aggressiva”?</p>

# %% [markdown]
# <img src='images/risposta4-a.jpg' alt='risposta4-a'></img>

# %% [markdown]
# <img src='images/risposta4-b.jpg' alt='risposta4-b'></img>

# %% [markdown]
# ## CONCLUSIONI

# %% [markdown]
# * Non c'è una zona di tiro preferita
# * Tanti tiri non significa tanti gol
# * Una difesa non deve essere aggressiva per funzionare
# * Una categoria inferiore non significa prestazioni peggiori
